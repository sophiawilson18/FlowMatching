# %%
import matplotlib.pyplot as plt
import csv

# %%
#ae_loss = [
#    0.007898153737187386, 0.006596043240278959, 0.002489914884790778, 0.00213263975456357,
#    0.0018527430947870016, 0.0031817040871828794, 0.0012132239062339067, 0.001077459892258048,
#    0.001315053435973823, 0.001705109840258956, 0.0006139646284282207, 0.0011772650759667158,
#    0.0011523247230798006, 0.000984070124104619, 0.0005885858554393053, 0.0007708509219810367,
#    0.000346805842127651, 0.000752769410610199, 0.0006222795927897096, 0.00038947080611251295,
#    0.00030417024390771985, 0.00045250868424773216, 0.0003378125838935375, 0.00117134815081954,
#    0.0012064166367053986, 0.0005751501303166151, 0.00044486785191111267, 0.0002837626961991191,
#    0.00021367109729908407, 0.00037075913860462606
#]
#
#val_loss = [
#    0.011504, 0.004469, 0.003101, 0.002981, 0.002483, 0.002708, 0.002933, 0.002229,
#    0.000964, 0.000956, 0.000877, 0.002239, 0.001022, 0.001170, 0.000602, 0.000601,
#    0.000629, 0.000707, 0.000869, 0.001084, 0.000431, 0.000427, 0.000480, 0.001116,
#    0.001334, 0.000852, 0.000381, 0.000366, 0.000362, 0.000566
#]


train_losses = [
    1.2237403708128702, 0.5904788031322615, 0.2843635278922461,
    0.1559608420871553, 0.09118601575360767, 0.05529189877278571,
    0.035247932870961014, 0.024013989009295723, 0.01728707755804949,
    0.012990223003573538, 0.010223788349124205, 0.00833623089788792,
    0.006969209067700874, 0.006001023267772758, 0.005212204711445208,
    0.0045768422480960864, 0.004047405531940361, 0.0036360124760263022,
    0.0032874190983074227, 0.0029856626729625056, 0.0027381639814813667,
    0.002511651574722713, 0.002320057053224272, 0.002172189197139925
]

val_losses = [
    1.144607, 0.347491, 0.173025, 0.089283, 0.049792, 0.029239,
    0.018646, 0.013114, 0.010151, 0.008003, 0.006419, 0.005724,
    0.004518, 0.004128, 0.003515, 0.003139, 0.002755, 0.002411,
    0.002175, 0.001977, 0.001794, 0.001616, 0.001558, 0.001406
]

# save as csv
#with open(f'AE_MSE_epochs30_lr0.0001_SpS5.csv', 'w') as f:
#    writer = csv.writer(f)
#    writer.writerows(zip(ae_loss, val_loss))

# %%
epochs = list(range(len(train_losses)))
plt.plot(epochs, train_losses, 'o-', label='Train loss', lw=2, color='black')
plt.plot(epochs, val_losses, 'o-', label='Val loss', lw=2, color='gray')
plt.xlabel('Epoch')
plt.ylabel('AE loss (MSE)')
plt.legend(loc = 'lower left', frameon=False)
#plt.title(f'AE: MSE loss, {len(train_losses)} epochs, 0.001 lr, min val loss: {min(val_losses)}')
plt.grid(True)
plt.xlim(-1, len(train_losses))
plt.yscale('log')


# save plot
#plt.savefig(f'AE_MSE_epochs30_lr0.0001_SpS5.png')
