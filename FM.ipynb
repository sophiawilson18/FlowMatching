# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train_losses = [
    0.339600234077527, 0.3176632022246336, 0.2647534842674549, 0.20510613180888004,
    0.1536069046610441, 0.1137439832664453, 0.0846743810062225, 0.06489435708484588,
    0.052282195557386446, 0.04431161863299517, 0.03892678173306661, 0.03475334769449173,
    0.031206809839185997, 0.02804291444615676, 0.025104484702341067, 0.022422386772739583,
    0.01993310681711405, 0.01762872239192709, 0.015579512099233958, 0.013677285337008727,
    0.012025449694826816, 0.01058020000704206, 0.009262050724086854, 0.008185514498454257,
    0.007198324700435385, 0.006327641065208576, 0.005592343498928807, 0.004921852564439178,
    0.004379193018524884, 0.0038822773073871547
]

val_losses = [
    0.24343792394715913, 0.20783341447917783, 0.15452546139760892, 0.10546786307680364,
    0.07167101430953765, 0.050772100192855815, 0.036301128490238775, 0.02572542320632813,
    0.02129538478899975, 0.01786716315629227, 0.015319540374437156, 0.01364190464991392,
    0.012415783641365717, 0.011205797045662696, 0.010317659570968576, 0.00933792985671637,
    0.008517501381587009, 0.007701832606286115, 0.007243015810524171, 0.006545415012717095,
    0.006178750834731879, 0.005630880708293039, 0.005271770415247931, 0.0049606394866120295,
    0.004780872988666655, 0.004490365119822019, 0.004320564379259868, 0.004212812374450495,
    0.004041416697650768, 0.0038991876122332655
]

# Plot the training and validation loss
epochs = list(range(len(train_losses)))
plt.plot(epochs, train_losses, 'o-', label='Train loss', lw=2, color='black')
plt.plot(epochs, val_losses, 'o-', label='Val loss', lw=2, color='gray')
plt.xlabel('Epoch')
plt.ylabel('FM loss (MSE)')
plt.legend(loc = 'lower left', frameon=False)
plt.title(f'FM: Scale 16, {len(train_losses)} epochs, min val loss: {min(np.round(val_losses, 6))}')
plt.grid(True)
plt.xlim(-1, len(train_losses))
plt.yscale('log')

# %%
losses = np.genfromtxt('results/all_data_scale16_lr5e-3_wd1e-4/losses.csv', delimiter=',')

train_losses = losses[:, 0]
val_losses = losses[:, 1]

# Plot the training and validation loss
epochs = list(range(len(train_losses)))
plt.plot(epochs, train_losses, 'o-', label='Train loss', lw=2, color='black')
plt.plot(epochs, val_losses, 'o-', label='Val loss', lw=2, color='gray')
plt.xlabel('Epoch')
plt.ylabel('FM loss (MSE)')
plt.legend(loc = 'lower left', frameon=False)
plt.title(f'FM: Scale 16, {len(train_losses)} epochs, min val loss: {min(np.round(val_losses, 6))}')
plt.grid(True)
plt.xlim(-1, len(train_losses))
plt.yscale('log')
#plt.savefig('results/all_data_scale16_lr5e-3_wd1e-4/losses.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
train_losses = [0.34542282581584066, 0.05477146312721774, 0.01583535627911711, 0.005905160494347732, 0.0028127302179853314, 0.0016194406693227168, 0.001154202835509478, 0.0008550715696914361,
                0.0007116137328346232, 0.0006410233846516846, 0.000588540126157638, 0.0005369617778839718, 0.000524104194106553, 0.0004662347289720654, 0.0004538666796964433,  0.00041614086003081063,
                0.00041080994427845414, 0.000384073166324559, 0.0003698415197022846, 0.00034235079902462793
]
                
val_losses = [0.0015155965455969853, 4.887661845788817e-05, 1.696869850145977e-05,  9.705525415285201e-06,  8.087547526952299e-06, 9.17345325942485e-06, 8.087547526952299e-06, 7.1615873082658534e-06,
              6.586028169204859e-06, 6.513008049215626e-06,  6.7662653603047485e-06, 6.42532724712311e-06, 6.181887313628207e-06, 6.1373371963068185e-06, 6.824249974626781e-06, 6.0697895897482445e-06,
              6.250402746712566e-06, 6.584217374565861e-06, 6.2938831244363314e-06, 5.830285825159515e-06

]

# Plot the training and validation loss
epochs = list(range(len(train_losses)))
plt.plot(epochs, train_losses, 'o-', label='Train loss', lw=2, color='black')
plt.plot(epochs, val_losses, 'o-', label='Val loss', lw=2, color='gray')
plt.xlabel('Epoch')
plt.ylabel('FM loss (MSE)')
plt.legend(loc = 'lower left', frameon=False)
plt.title(f'FM: Scale 16, {len(train_losses)} epochs, min val loss: {min(np.round(val_losses, 6))}')
plt.grid(True)
plt.xlim(-1, len(train_losses))
plt.yscale('log')
